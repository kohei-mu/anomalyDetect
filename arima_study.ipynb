# %%
library(forecast)
# Out:
# Warning message:
# "package 'forecast' was built under R version 3.4.4"

# %%
x1_ma<-arima.sim(n=200,list(ma=1)) 
plot(x1_ma)
x2_ma<-arima.sim(n=200,list(ma=-1))
plot(x2_ma)
# Out:
# plot without title
# plot without title

# %%
x1_ar<-arima.sim(n=200,list(ar=0.5))
plot(x1_ar)
x2_ar<-arima.sim(n=200,list(ar=-0.5))
plot(x2_ar)
# Out:
# plot without title
# plot without title

# %%
x1_arima<-arima.sim(n=200,list(order=c(2,0,1),ar=c(0.2,-0.1),ma=0.1))
plot(x1_arima)
x2_arima<-arima.sim(n=200,list(order=c(1,1,2),ar=0.3,ma=c(0.3,-0.4)))
plot(x2_arima)
# Out:
# plot without title
# plot without title

# %%
auto.arima(x1_arima,max.p=2,max.q=2,stepwise=T,trace=T)
# Out:
#  Fitting models using approximations to speed things up...
#
#  ARIMA(2,1,2) with drift         : 570.5485
#  ARIMA(0,1,0) with drift         : 678.8516
#  ARIMA(1,1,0) with drift         : 667.8137
#  ARIMA(0,1,1) with drift         : 598.3226
#  ARIMA(0,1,0)                    : 676.8169
#  ARIMA(1,1,2) with drift         : Inf
#  ARIMA(2,1,1) with drift         : 569.7887
#  ARIMA(2,1,1)                    : 567.7349
#  ARIMA(1,1,1)                    : Inf
#  ARIMA(2,1,0)                    : 631.3652
#  ARIMA(2,1,2)                    : 568.435
#  ARIMA(1,1,0)                    : 665.7535
#
#  Now re-fitting the best model(s) without approximations...
#
#  ARIMA(2,1,1)                    : 570.3711
#
#  Best model: ARIMA(2,1,1)
# Series: x1_arima
# ARIMA(2,1,1)
#
# Coefficients:
#          ar1      ar2      ma1
#       0.1907  -0.2954  -0.9315
# s.e.  0.0739   0.0727   0.0416
#
# sigma^2 estimated as 0.9904:  log likelihood=-281.08
# AIC=570.16   AICc=570.37   BIC=583.34

# %%
x1_forecast<-Arima(x1_arima,order=c(2,0,1))
x2_forecast<-Arima(x2_arima,order=c(5,1,2))
plot(forecast(x1_forecast,level=c(50,95),h=150))
plot(forecast(x2_forecast,level=c(50,95),h=150))
# Out:
# Plot with title "Forecasts from ARIMA(2,0,1) with non-zero mean"
# Plot with title "Forecasts from ARIMA(5,1,2)"

# %%
xt.arima1<-auto.arima(x1_arima,trace=T,stepwise=T,seasonal=T)
plot(forecast(xt.arima1,range=c(50,95),h=150))
xt.arima2<-auto.arima(x2_arima,trace=T,stepwise=T,seasonal=T)
plot(forecast(xt.arima2,range=c(50,95),h=150))
# Out:
#  Fitting models using approximations to speed things up...
#
#  ARIMA(2,1,2) with drift         : 570.5485
#  ARIMA(0,1,0) with drift         : 678.8516
#  ARIMA(1,1,0) with drift         : 667.8137
#  ARIMA(0,1,1) with drift         : 598.3226
#  ARIMA(0,1,0)                    : 676.8169
#  ARIMA(1,1,2) with drift         : Inf
#  ARIMA(3,1,2) with drift         : 575.1862
#  ARIMA(2,1,1) with drift         : 569.7887
#  ARIMA(2,1,1)                    : 567.7349
#  ARIMA(1,1,1)                    : Inf
#  ARIMA(3,1,1)                    : 570.2072
#  ARIMA(2,1,0)                    : 631.3652
#  ARIMA(2,1,2)                    : 568.435
#  ARIMA(1,1,0)                    : 665.7535
#  ARIMA(3,1,2)                    : 573.057
#
#  Now re-fitting the best model(s) without approximations...
#
#  ARIMA(2,1,1)                    : 570.3711
#
#  Best model: ARIMA(2,1,1)
# Warning message in forecast.Arima(xt.arima1, range = c(50, 95), h = 150):
# "The non-existent range arguments will be ignored."
#  Fitting models using approximations to speed things up...
#
#  ARIMA(2,1,2) with drift         : 564.9836
#  ARIMA(0,1,0) with drift         : 653.847
#  ARIMA(1,1,0) with drift         : 618.1298
#  ARIMA(0,1,1) with drift         : 563.1747
#  ARIMA(0,1,0)                    : 652.6113
#  ARIMA(1,1,1) with drift         : 565.6534
#  ARIMA(0,1,2) with drift         : 564.8717
#  ARIMA(1,1,2) with drift         : 562.4979
#  ARIMA(1,1,2)                    : 561.5972
#  ARIMA(0,1,2)                    : 563.1585
#  ARIMA(2,1,2)                    : 563.7925
#  ARIMA(1,1,1)                    : 563.9797
#  ARIMA(1,1,3)                    : 562.2603
#  ARIMA(0,1,1)                    : 561.437
#
#  Now re-fitting the best model(s) without approximations...
#
#  ARIMA(0,1,1)                    : 562.6634
#
#  Best model: ARIMA(0,1,1)
# Warning message in forecast.Arima(xt.arima2, range = c(50, 95), h = 150):
# "The non-existent range arguments will be ignored."
# Plot with title "Forecasts from ARIMA(2,1,1)"
# Plot with title "Forecasts from ARIMA(0,1,1)"

# %%
y1<-rep(c(3,5,12,4),20)
y2<-20+20*sin(seq(from=-0.5*pi,to=0,length.out=80))
y<-y1+y2+rnorm(mean=0,sd=3,n=80)
yt<-ts(as.numeric(y),frequency=4)
plot(yt)
# Out:
# plot without title

# %%
yt.arima<-auto.arima(yt,trace=T,stepwise=T,seasonal=T)
plot(forecast(yt.arima,range=c(50,95),h=150))
# Out:
#  ARIMA(2,0,2)(1,1,1)[4] with drift         : Inf
#  ARIMA(0,0,0)(0,1,0)[4] with drift         : 445.8968
#  ARIMA(1,0,0)(1,1,0)[4] with drift         : 425.7088
#  ARIMA(0,0,1)(0,1,1)[4] with drift         : Inf
#  ARIMA(0,0,0)(0,1,0)[4]                    : 449.1483
#  ARIMA(1,0,0)(0,1,0)[4] with drift         : 447.6937
#  ARIMA(1,0,0)(2,1,0)[4] with drift         : 424.8343
#  ARIMA(1,0,0)(2,1,1)[4] with drift         : Inf
#  ARIMA(0,0,0)(2,1,0)[4] with drift         : 422.6823
#  ARIMA(0,0,1)(2,1,0)[4] with drift         : 424.7927
#  ARIMA(1,0,1)(2,1,0)[4] with drift         : 422.7417
#  ARIMA(0,0,0)(2,1,0)[4]                    : 440.1353
#  ARIMA(0,0,0)(1,1,0)[4] with drift         : 423.5303
#  ARIMA(0,0,0)(2,1,1)[4] with drift         : Inf
#
#  Best model: ARIMA(0,0,0)(2,1,0)[4] with drift
# Warning message in forecast.Arima(yt.arima, range = c(50, 95), h = 150):
# "The non-existent range arguments will be ignored."
# Plot with title "Forecasts from ARIMA(0,0,0)(2,1,0)[4] with drift"

# %%
yt.arima<-auto.arima(yt,trace=T,stepwise=T,seasonal=F)
plot(forecast(yt.arima,range=c(50,95),h=150))
# Out:
#  ARIMA(2,1,2)           with drift         : 478.9918
#  ARIMA(0,1,0)           with drift         : 542.6137
#  ARIMA(1,1,0)           with drift         : 526.5607
#  ARIMA(0,1,1)           with drift         : Inf
#  ARIMA(0,1,0)                              : 540.6444
#  ARIMA(1,1,2)           with drift         : Inf
#  ARIMA(3,1,2)           with drift         : Inf
#  ARIMA(2,1,1)           with drift         : 480.7692
#  ARIMA(2,1,3)           with drift         : Inf
#  ARIMA(1,1,1)           with drift         : Inf
#  ARIMA(3,1,3)           with drift         : Inf
#  ARIMA(2,1,2)                              : 484.4827
#
#  Best model: ARIMA(2,1,2)           with drift
# Warning message in forecast.Arima(yt.arima, range = c(50, 95), h = 150):
# "The non-existent range arguments will be ignored."
# Plot with title "Forecasts from ARIMA(2,1,2) with drift"

# %%
yt.arima_noI<-Arima(yt,order=c(5,1,1))
plot(forecast(yt.arima_noI,range=c(50,95),h=150))
# Out:
# Warning message in forecast.Arima(yt.arima_noI, range = c(50, 95), h = 150):
# "The non-existent range arguments will be ignored."
# Plot with title "Forecasts from ARIMA(5,1,1)"

# %%
tsdisplay(x1_arima)
tsdisplay(x2_arima)
# Out:
# Plot with title ""
# Plot with title ""
